# %% [markdown]
# # Convert Kinetics Library to Training Reactions Script
#
# Specify the kinetics library name below and run the script.  It automatically overwrites the training reactions files it needs to.  Then you should commit those files.
#
# This script only trains safely.  In other words, if a single match from an RMG family is found, a training reaction is created.  Sometimes, there are no matches from RMG reaction families, or multiple matches.  This indicates an error that requires manual fixing, and a printout is given in the script.

# %%
libraryName = '2012_Kislov_Phenyl_Propene'

# %%
from rmgpy.data.rmg import RMGDatabase
from rmgpy.chemkin import saveChemkinFile, saveSpeciesDictionary
from rmgpy.rmg.model import Species
from rmgpy import settings
from IPython.display import display, Image

# %%
# Function to draw reaction templates
def drawTemplate(template):
    import pydot
    for entry in template:
        group = entry.item
        graph = pydot.Dot(graph_type='graph', dpi="52")
        for index, atom in enumerate(group.atoms):
            atomType = '{0!s} '.format(atom.label if atom.label != '' else '')
            atomType += ','.join([atomType.label for atomType in atom.atomType])
            atomType = '"' + atomType + '"'
            graph.add_node(pydot.Node(name=str(index + 1), label=atomType, fontname="Helvetica", fontsize="16"))
        for atom1 in group.atoms:
            for atom2, bond in atom1.bonds.iteritems():
                index1 = group.atoms.index(atom1)
                index2 = group.atoms.index(atom2)
                if index1 < index2:
                    bondType = ','.join([order for order in bond.order])
                    bondType = '"' + bondType + '"'
                    graph.add_edge(pydot.Edge(src=str(index1 + 1), dst=str(index2 + 1), label=bondType, fontname="Helvetica", fontsize="16"))

        img = graph.create_png(prog='neato')
        print entry.label
        display(Image(img))

# %% [markdown]
# ## load lib_rxn

# %%
database = RMGDatabase()
database.load(settings['database.directory'], kineticsFamilies='all', reactionLibraries = [libraryName], kineticsDepositories='all')

# %% [markdown]
# ## generate fam_rxn, spec replacement and get reactionDict

# %%
reactionDict = {}
kineticLibrary = database.kinetics.libraries[libraryName]
for index, entry in kineticLibrary.entries.iteritems():
    lib_rxn = entry.item
    lib_rxn.kinetics = entry.data 
    lib_rxn.index = entry.index
    lib_rxn.kinetics.comment = entry.label # Assign the entry's label to the comment
    # Let's make RMG try to generate this reaction from the families!
    fam_rxn_list = []
    rxt_mol_mutation_num = 1
    pdt_mol_mutation_num = 1
    for reactant in lib_rxn.reactants:
        rxt_mol_mutation_num *= len(reactant.molecule)

    for product in lib_rxn.products:
        pdt_mol_mutation_num *= len(product.molecule)

    for mutation_i in range(rxt_mol_mutation_num):
        rxts_mol = [spc.molecule[mutation_i%(len(spc.molecule))] for spc in lib_rxn.reactants]
        pdts_mol = [spc.molecule[0] for spc in lib_rxn.products]
        fam_rxn_list.extend(database.kinetics.generateReactionsFromFamilies(
                        reactants=rxts_mol, products=pdts_mol))


    if len(fam_rxn_list) == 1:
        
        print "One RMG match for this reaction."
              
        fam_rxn = fam_rxn_list[0]

        # danger: the fam_rxn may have switched the reactants with products
        # fam_rxn is survived from def filterReactions
        # so it's matched with lib_rxn only we have to 
        # determine the direction
        lib_reactants = [r for r in lib_rxn.reactants]        
        fam_reactants = [r for r in fam_rxn.reactants]
        for lib_reactant in lib_reactants:
            for fam_reactant in fam_reactants:
                if lib_reactant.isIsomorphic(fam_reactant):
                    fam_reactants.remove(fam_reactant)
                    break

        lib_products = [r for r in lib_rxn.products]        
        fam_products = [r for r in fam_rxn.products]
        for lib_product in lib_products:
            for fam_product in fam_products:
                if lib_product.isIsomorphic(fam_product):
                    fam_products.remove(fam_product)
                    break

        forward = not (len(fam_reactants) != 0 or len(fam_products) != 0)
        # find the labeled atoms using family and reactants & products from fam_rxn
        family_database = database.kinetics.families[fam_rxn.family]
        family_database.addAtomLabelsForReaction(fam_rxn)
        # species replacement so that labeledAtoms is retored
        if forward:
            lib_rxn.reactants = fam_rxn.reactants
            lib_rxn.products = fam_rxn.products
        else:
            lib_rxn.reactants = fam_rxn.products
            lib_rxn.products = fam_rxn.reactants
        if fam_rxn.family in reactionDict:
            reactionDict[fam_rxn.family].append(lib_rxn)
        else:
            reactionDict[fam_rxn.family] = [lib_rxn]
            
            
        template = database.kinetics.families[fam_rxn.family].getReactionTemplate(fam_rxn)
        print ''
        display(fam_rxn)
        print ''
        print 'Reactant SMILES:'
        for reactant in lib_rxn.reactants:
            print reactant.molecule[0].toSMILES()
        print 'Product SMILES'
        for product in lib_rxn.products:
            print product.molecule[0].toSMILES()
        print ''
        print 'Matched Family: {}'.format(fam_rxn.family)    
        print 'Matched Template: {}'.format([entry.label for entry in template])
        drawTemplate(template)
        print '==============='
        
    elif len(fam_rxn_list) == 0:
        print "Sad :( There are no matches.  This is a magic reaction or has chemistry that should be made into a new reaction family"
        print ''
        print lib_rxn
        print ''
        print 'Reactant SMILES:'
        for reactant in lib_rxn.reactants:
            print reactant.molecule[0].toSMILES()
        print 'Product SMILES:'
        for product in lib_rxn.products:
            print product.molecule[0].toSMILES()
        print '==============='
    else:
        print "There are multiple RMG matches for this reaction. You have to manually create this training reaction"
        print ''
        print lib_rxn
        print ''
        print 'Reactant SMILES:'
        for reactant in lib_rxn.reactants:
            print reactant.molecule[0].toSMILES()
        print 'Product SMILES'
        for product in lib_rxn.products:
            print product.molecule[0].toSMILES()
        print ''
        print 'The following families and templates were matched:'
        for rxn in fam_rxn_list:
            print 'Matched Family: {}'.format(rxn.family)      
            
            # find the labeled atoms using family and reactants & products from fam_rxn
            family_database = database.kinetics.families[rxn.family]
            family_database.addAtomLabelsForReaction(rxn)

            template = database.kinetics.families[rxn.family].getReactionTemplate(rxn)
            print 'Matched Template: {}'.format([entry.label for entry in template])
            drawTemplate(template)
            
            print ''
            display(rxn)
        
        
        print '==============='
# Out:
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# C6H5 + C3H6 <=> i1
#
# Reactant SMILES:
# [c]1ccccc1
# C=CC
# Product SMILES
# C[CH]Cc1ccccc1
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-HH_Cds-Cs\\H3/H', 'CbJ']
# Cds-HH_Cds-Cs\H3/H
# CbJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC")]), Species(label="", molecule=[Molecule(SMILES="[c]1ccccc1")])], products=[Species(label="", molecule=[Molecule(SMILES="C[CH]Cc1ccccc1")])], pairs=[[Molecule(SMILES="[c]1ccccc1"), Molecule(SMILES="C[CH]Cc1ccccc1")], [Molecule(SMILES="C=CC"), Molecule(SMILES="C[CH]Cc1ccccc1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-HH_Cds-Cs\\H3/H', 'CdsJ-Cd']
# Cds-HH_Cds-Cs\H3/H
# CdsJ-Cd
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC")]), Species(label="", molecule=[Molecule(SMILES="[C]1=CC=CC=C1")])], products=[Species(label="", molecule=[Molecule(SMILES="C[CH]CC1C=CC=CC=1")])], pairs=[[Molecule(SMILES="[C]1=CC=CC=C1"), Molecule(SMILES="C[CH]CC1C=CC=CC=1")], [Molecule(SMILES="C=CC"), Molecule(SMILES="C[CH]CC1C=CC=CC=1")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# C6H5 + C3H6 <=> i2
#
# Reactant SMILES:
# [c]1ccccc1
# C=CC
# Product SMILES
# [CH2]C(C)c1ccccc1
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CsH_Cds-HH', 'CbJ']
# Cds-CsH_Cds-HH
# CbJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC")]), Species(label="", molecule=[Molecule(SMILES="[c]1ccccc1")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH2]C(C)c1ccccc1")])], pairs=[[Molecule(SMILES="[c]1ccccc1"), Molecule(SMILES="[CH2]C(C)c1ccccc1")], [Molecule(SMILES="C=CC"), Molecule(SMILES="[CH2]C(C)c1ccccc1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CsH_Cds-HH', 'CdsJ-Cd']
# Cds-CsH_Cds-HH
# CdsJ-Cd
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC")]), Species(label="", molecule=[Molecule(SMILES="[C]1=CC=CC=C1")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")])], pairs=[[Molecule(SMILES="[C]1=CC=CC=C1"), Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")], [Molecule(SMILES="C=CC"), Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# C6H5 + C3H6 <=> CH3CHCH + C6H6
#
# Reactant SMILES:
# [c]1ccccc1
# C=CC
# Product SMILES
# [CH]=CC
# c1ccccc1
#
# The following families and templates were matched:
# Matched Family: H_Abstraction
# Matched Template: ['Cd/H2/NonDeC', 'Cb_rad']
# Cd/H2/NonDeC
# Cb_rad
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC")]), Species(label="", molecule=[Molecule(SMILES="[c]1ccccc1")])], products=[Species(label="", molecule=[Molecule(SMILES="c1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="[CH]=CC")])], degeneracy=2, pairs=[[Molecule(SMILES="[c]1ccccc1"), Molecule(SMILES="c1ccccc1")], [Molecule(SMILES="C=CC"), Molecule(SMILES="[CH]=CC")]])
# Matched Family: H_Abstraction
# Matched Template: ['Cd/H2/NonDeC', 'Cd_rad/Cd']
# Cd/H2/NonDeC
# Cd_rad/Cd
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC")]), Species(label="", molecule=[Molecule(SMILES="[C]1=CC=CC=C1")])], products=[Species(label="", molecule=[Molecule(SMILES="C1=CC=CC=C1")]), Species(label="", molecule=[Molecule(SMILES="[CH]=CC")])], degeneracy=2, pairs=[[Molecule(SMILES="[C]1=CC=CC=C1"), Molecule(SMILES="C1=CC=CC=C1")], [Molecule(SMILES="C=CC"), Molecule(SMILES="[CH]=CC")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# C6H5 + C3H6 <=> CH3CCH2 + C6H6
#
# Reactant SMILES:
# [c]1ccccc1
# C=CC
# Product SMILES
# C=[C]C
# c1ccccc1
#
# The following families and templates were matched:
# Matched Family: H_Abstraction
# Matched Template: ['Cd/H/NonDeC', 'Cb_rad']
# Cd/H/NonDeC
# Cb_rad
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC")]), Species(label="", molecule=[Molecule(SMILES="[c]1ccccc1")])], products=[Species(label="", molecule=[Molecule(SMILES="c1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="C=[C]C")])], pairs=[[Molecule(SMILES="[c]1ccccc1"), Molecule(SMILES="c1ccccc1")], [Molecule(SMILES="C=CC"), Molecule(SMILES="C=[C]C")]])
# Matched Family: H_Abstraction
# Matched Template: ['Cd/H/NonDeC', 'Cd_rad/Cd']
# Cd/H/NonDeC
# Cd_rad/Cd
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC")]), Species(label="", molecule=[Molecule(SMILES="[C]1=CC=CC=C1")])], products=[Species(label="", molecule=[Molecule(SMILES="C1=CC=CC=C1")]), Species(label="", molecule=[Molecule(SMILES="C=[C]C")])], pairs=[[Molecule(SMILES="[C]1=CC=CC=C1"), Molecule(SMILES="C1=CC=CC=C1")], [Molecule(SMILES="C=CC"), Molecule(SMILES="C=[C]C")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# C6H5 + C3H6 <=> CH2CHCH2 + C6H6
#
# Reactant SMILES:
# [c]1ccccc1
# C=CC
# Product SMILES
# [CH2]C=C
# c1ccccc1
#
# The following families and templates were matched:
# Matched Family: H_Abstraction
# Matched Template: ['C/H3/Cd\\H_Cd\\H2', 'Cb_rad']
# C/H3/Cd\H_Cd\H2
# Cb_rad
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC")]), Species(label="", molecule=[Molecule(SMILES="[c]1ccccc1")])], products=[Species(label="", molecule=[Molecule(SMILES="c1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="[CH2]C=C")])], degeneracy=3, pairs=[[Molecule(SMILES="[c]1ccccc1"), Molecule(SMILES="c1ccccc1")], [Molecule(SMILES="C=CC"), Molecule(SMILES="[CH2]C=C")]])
# Matched Family: H_Abstraction
# Matched Template: ['C/H3/Cd\\H_Cd\\H2', 'Cd_rad/Cd']
# C/H3/Cd\H_Cd\H2
# Cd_rad/Cd
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC")]), Species(label="", molecule=[Molecule(SMILES="[C]1=CC=CC=C1")])], products=[Species(label="", molecule=[Molecule(SMILES="C1=CC=CC=C1")]), Species(label="", molecule=[Molecule(SMILES="[CH2]C=C")])], degeneracy=3, pairs=[[Molecule(SMILES="[C]1=CC=CC=C1"), Molecule(SMILES="C1=CC=CC=C1")], [Molecule(SMILES="C=CC"), Molecule(SMILES="[CH2]C=C")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i2 <=> p4 + H
#
# Reactant SMILES:
# [CH2]C(C)c1ccccc1
# Product SMILES
# C=C(C)c1ccccc1
# [H]
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CbCs_Cds-HH', 'HJ']
# Cds-CbCs_Cds-HH
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=C(C)c1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH2]C(C)c1ccccc1")])], pairs=[[Molecule(SMILES="C=C(C)c1ccccc1"), Molecule(SMILES="[CH2]C(C)c1ccccc1")], [Molecule(SMILES="[H]"), Molecule(SMILES="[CH2]C(C)c1ccccc1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CdCs_Cds-HH', 'HJ']
# Cds-CdCs_Cds-HH
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=C(C)C1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")])], pairs=[[Molecule(SMILES="C=C(C)C1C=CC=CC=1"), Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")], [Molecule(SMILES="[H]"), Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i2 <=> p1 + CH3
#
# Reactant SMILES:
# [CH2]C(C)c1ccccc1
# Product SMILES
# C=Cc1ccccc1
# [CH3]
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CbH_Cds-HH', 'CsJ-HHH']
# Cds-CbH_Cds-HH
# CsJ-HHH
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=Cc1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="[CH3]")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH2]C(C)c1ccccc1")])], pairs=[[Molecule(SMILES="C=Cc1ccccc1"), Molecule(SMILES="[CH2]C(C)c1ccccc1")], [Molecule(SMILES="[CH3]"), Molecule(SMILES="[CH2]C(C)c1ccccc1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CdH_Cds-HH', 'CsJ-HHH']
# Cds-CdH_Cds-HH
# CsJ-HHH
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[CH3]")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")])], pairs=[[Molecule(SMILES="C=CC1C=CC=CC=1"), Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")], [Molecule(SMILES="[CH3]"), Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")]])
# ===============
# One RMG match for this reaction.
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")])], products=[Species(label="", molecule=[Molecule(SMILES="CC1CC12[CH]C=CC=C2")])], pairs=[[Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1"), Molecule(SMILES="CC1CC12[CH]C=CC=C2")]])
# Reactant SMILES:
# [CH2]C(C)C1C=CC=CC=1
# Product SMILES
# CC1CC12[CH]C=CC=C2
#
# Matched Family: Intra_R_Add_Exocyclic
# Matched Template: ['R4_S_D', 'doublebond_intra_HDe_secDe', 'radadd_intra_cs2H']
# R4_S_D
# doublebond_intra_HDe_secDe
# radadd_intra_cs2H
# ===============
# One RMG match for this reaction.
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")])], products=[Species(label="", molecule=[Molecule(SMILES="CC1CC2[CH]C=CC=C12")])], degeneracy=2, pairs=[[Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1"), Molecule(SMILES="CC1CC2[CH]C=CC=C12")]])
# Reactant SMILES:
# [CH2]C(C)C1C=CC=CC=1
# Product SMILES
# CC1CC2[CH]C=CC=C12
#
# Matched Family: Intra_R_Add_Exocyclic
# Matched Template: ['Rn2c6_alpha', 'doublebond_intra_HCd_pri', 'radadd_intra_cs2H']
# Rn2c6_alpha
# doublebond_intra_HCd_pri
# radadd_intra_cs2H
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i2 <=> i9
#
# Reactant SMILES:
# [CH2]C(C)c1ccccc1
# Product SMILES
# C[C](C)c1ccccc1
#
# The following families and templates were matched:
# Matched Family: intra_H_migration
# Matched Template: ['R2H_S', 'C_rad_out_2H', 'Cs_H_out_AromDe']
# R2H_S
# C_rad_out_2H
# Cs_H_out_AromDe
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="[CH2]C(C)c1ccccc1")])], products=[Species(label="", molecule=[Molecule(SMILES="C[C](C)c1ccccc1")])], pairs=[[Molecule(SMILES="[CH2]C(C)c1ccccc1"), Molecule(SMILES="C[C](C)c1ccccc1")]])
# Matched Family: intra_H_migration
# Matched Template: ['R2H_S', 'C_rad_out_2H', 'Cs_H_out_Cd']
# R2H_S
# C_rad_out_2H
# Cs_H_out_Cd
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1")])], products=[Species(label="", molecule=[Molecule(SMILES="C[C](C)C1C=CC=CC=1")])], pairs=[[Molecule(SMILES="[CH2]C(C)C1C=CC=CC=1"), Molecule(SMILES="C[C](C)C1C=CC=CC=1")]])
# ===============
# Sad :( There are no matches.  This is a magic reaction or has chemistry that should be made into a new reaction family
#
# i2 <=> i10
#
# Reactant SMILES:
# [CH2]C(C)c1ccccc1
# Product SMILES:
# C=C(C)C1[CH]C=CC=C1
# ===============
# One RMG match for this reaction.
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C[CH]CC1C=CC=CC=1")])], products=[Species(label="", molecule=[Molecule(SMILES="CC1CC12[CH]C=CC=C2")])], pairs=[[Molecule(SMILES="C[CH]CC1C=CC=CC=1"), Molecule(SMILES="CC1CC12[CH]C=CC=C2")]])
# Reactant SMILES:
# C[CH]CC1C=CC=CC=1
# Product SMILES
# CC1CC12[CH]C=CC=C2
#
# Matched Family: Intra_R_Add_Exocyclic
# Matched Template: ['R4_S_D', 'doublebond_intra_HDe_secDe', 'radadd_intra_csHNd']
# R4_S_D
# doublebond_intra_HDe_secDe
# radadd_intra_csHNd
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i1 <=> p2 + H
#
# Reactant SMILES:
# C[CH]Cc1ccccc1
# Product SMILES
# C=CCc1ccccc1
# [H]
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-HH_Cds-CsH', 'HJ']
# Cds-HH_Cds-CsH
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CCc1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C[CH]Cc1ccccc1")])], pairs=[[Molecule(SMILES="C=CCc1ccccc1"), Molecule(SMILES="C[CH]Cc1ccccc1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C[CH]Cc1ccccc1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-HH_Cds-CsH', 'HJ']
# Cds-HH_Cds-CsH
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CCC1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C[CH]CC1C=CC=CC=1")])], pairs=[[Molecule(SMILES="C=CCC1C=CC=CC=1"), Molecule(SMILES="C[CH]CC1C=CC=CC=1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C[CH]CC1C=CC=CC=1")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i1 <=> p3 + H
#
# Reactant SMILES:
# C[CH]Cc1ccccc1
# Product SMILES
# CC=Cc1ccccc1
# [H]
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CbH_Cds-CsH', 'HJ']
# Cds-CbH_Cds-CsH
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="CC=Cc1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C[CH]Cc1ccccc1")])], pairs=[[Molecule(SMILES="CC=Cc1ccccc1"), Molecule(SMILES="C[CH]Cc1ccccc1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C[CH]Cc1ccccc1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CdH_Cds-CsH', 'HJ']
# Cds-CdH_Cds-CsH
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="CC=CC1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C[CH]CC1C=CC=CC=1")])], pairs=[[Molecule(SMILES="CC=CC1C=CC=CC=1"), Molecule(SMILES="C[CH]CC1C=CC=CC=1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C[CH]CC1C=CC=CC=1")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i1 <=> i4
#
# Reactant SMILES:
# C[CH]Cc1ccccc1
# Product SMILES
# [CH2]CCc1ccccc1
#
# The following families and templates were matched:
# Matched Family: intra_H_migration
# Matched Template: ['R2H_S', 'C_rad_out_H/NonDeC', 'Cs_H_out_2H']
# R2H_S
# C_rad_out_H/NonDeC
# Cs_H_out_2H
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C[CH]Cc1ccccc1")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH2]CCc1ccccc1")])], degeneracy=3, pairs=[[Molecule(SMILES="C[CH]Cc1ccccc1"), Molecule(SMILES="[CH2]CCc1ccccc1")]])
# Matched Family: intra_H_migration
# Matched Template: ['R2H_S', 'C_rad_out_H/NonDeC', 'Cs_H_out_2H']
# R2H_S
# C_rad_out_H/NonDeC
# Cs_H_out_2H
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C[CH]CC1C=CC=CC=1")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH2]CCC1C=CC=CC=1")])], degeneracy=3, pairs=[[Molecule(SMILES="C[CH]CC1C=CC=CC=1"), Molecule(SMILES="[CH2]CCC1C=CC=CC=1")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i1 <=> i7
#
# Reactant SMILES:
# C[CH]Cc1ccccc1
# Product SMILES
# CC[CH]c1ccccc1
#
# The following families and templates were matched:
# Matched Family: intra_H_migration
# Matched Template: ['R2H_S', 'C_rad_out_H/NonDeC', 'Cs_H_out_H/AromDe']
# R2H_S
# C_rad_out_H/NonDeC
# Cs_H_out_H/AromDe
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C[CH]Cc1ccccc1")])], products=[Species(label="", molecule=[Molecule(SMILES="CC[CH]c1ccccc1")])], degeneracy=2, pairs=[[Molecule(SMILES="C[CH]Cc1ccccc1"), Molecule(SMILES="CC[CH]c1ccccc1")]])
# Matched Family: intra_H_migration
# Matched Template: ['R2H_S', 'C_rad_out_H/NonDeC', 'Cs_H_out_H/Cd']
# R2H_S
# C_rad_out_H/NonDeC
# Cs_H_out_H/Cd
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C[CH]CC1C=CC=CC=1")])], products=[Species(label="", molecule=[Molecule(SMILES="CC[CH]C1C=CC=CC=1")])], degeneracy=2, pairs=[[Molecule(SMILES="C[CH]CC1C=CC=CC=1"), Molecule(SMILES="CC[CH]C1C=CC=CC=1")]])
# ===============
# Sad :( There are no matches.  This is a magic reaction or has chemistry that should be made into a new reaction family
#
# i1 <=> i6
#
# Reactant SMILES:
# C[CH]Cc1ccccc1
# Product SMILES:
# C=CCC1=CC=C[CH]C1
# ===============
# One RMG match for this reaction.
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C1C=CC2CC=C2C=1")]), Species(label="", molecule=[Molecule(SMILES="[CH3]")])], products=[Species(label="", molecule=[Molecule(SMILES="CC1CC2C=CC=C[C]12")])], pairs=[[Molecule(SMILES="C1C=CC2CC=C2C=1"), Molecule(SMILES="CC1CC2C=CC=C[C]12")], [Molecule(SMILES="[CH3]"), Molecule(SMILES="CC1CC2C=CC=C[C]12")]])
# Reactant SMILES:
# CC1CC2C=CC=C[C]12
# Product SMILES
# C1C=CC2CC=C2C=1
# [CH3]
#
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CsH_Cds-CdCs', 'CsJ-HHH']
# Cds-CsH_Cds-CdCs
# CsJ-HHH
# ===============
# One RMG match for this reaction.
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="CC1CC2=CC=CC=C21")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="CC1CC2[CH]C=CC=C12")])], degeneracy=2, pairs=[[Molecule(SMILES="CC1CC2=CC=CC=C21"), Molecule(SMILES="CC1CC2[CH]C=CC=C12")], [Molecule(SMILES="[H]"), Molecule(SMILES="CC1CC2[CH]C=CC=C12")]])
# Reactant SMILES:
# CC1CC2[CH]C=CC=C12
# Product SMILES
# CC1CC2=CC=CC=C21
# [H]
#
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cb-R!H_Cb-H', 'HJ']
# Cb-R!H_Cb-H
# HJ
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i9 <=> p4 + H
#
# Reactant SMILES:
# C[C](C)c1ccccc1
# Product SMILES
# C=C(C)c1ccccc1
# [H]
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-HH_Cds-CbCs', 'HJ']
# Cds-HH_Cds-CbCs
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=C(C)c1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C[C](C)c1ccccc1")])], pairs=[[Molecule(SMILES="C=C(C)c1ccccc1"), Molecule(SMILES="C[C](C)c1ccccc1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C[C](C)c1ccccc1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-HH_Cds-CdCs', 'HJ']
# Cds-HH_Cds-CdCs
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=C(C)C1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C[C](C)C1C=CC=CC=1")])], pairs=[[Molecule(SMILES="C=C(C)C1C=CC=CC=1"), Molecule(SMILES="C[C](C)C1C=CC=CC=1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C[C](C)C1C=CC=CC=1")]])
# ===============
# One RMG match for this reaction.
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=C(C)C1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C=C(C)C1[CH]C=CC=C1")])], degeneracy=2, pairs=[[Molecule(SMILES="C=C(C)C1C=CC=CC=1"), Molecule(SMILES="C=C(C)C1[CH]C=CC=C1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C=C(C)C1[CH]C=CC=C1")]])
# Reactant SMILES:
# C=C(C)C1[CH]C=CC=C1
# Product SMILES
# C=C(C)C1C=CC=CC=1
# [H]
#
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cb-R!H_Cb-H', 'HJ']
# Cb-R!H_Cb-H
# HJ
# ===============
# One RMG match for this reaction.
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="[CH2]CCC1C=CC=CC=1")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH]1C=CC=C2CCCC12")])], degeneracy=2, pairs=[[Molecule(SMILES="[CH2]CCC1C=CC=CC=1"), Molecule(SMILES="[CH]1C=CC=C2CCCC12")]])
# Reactant SMILES:
# [CH2]CCC1C=CC=CC=1
# Product SMILES
# [CH]1C=CC=C2CCCC12
#
# Matched Family: Intra_R_Add_Exocyclic
# Matched Template: ['Rn3c6_alpha', 'doublebond_intra_HCd_pri', 'radadd_intra_cs2H']
# Rn3c6_alpha
# doublebond_intra_HCd_pri
# radadd_intra_cs2H
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i4 <=> p2 + H
#
# Reactant SMILES:
# [CH2]CCc1ccccc1
# Product SMILES
# C=CCc1ccccc1
# [H]
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CsH_Cds-HH', 'HJ']
# Cds-CsH_Cds-HH
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CCc1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH2]CCc1ccccc1")])], pairs=[[Molecule(SMILES="C=CCc1ccccc1"), Molecule(SMILES="[CH2]CCc1ccccc1")], [Molecule(SMILES="[H]"), Molecule(SMILES="[CH2]CCc1ccccc1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CsH_Cds-HH', 'HJ']
# Cds-CsH_Cds-HH
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CCC1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="[CH2]CCC1C=CC=CC=1")])], pairs=[[Molecule(SMILES="C=CCC1C=CC=CC=1"), Molecule(SMILES="[CH2]CCC1C=CC=CC=1")], [Molecule(SMILES="[H]"), Molecule(SMILES="[CH2]CCC1C=CC=CC=1")]])
# ===============
# One RMG match for this reaction.
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C1C=CC2CCCC=2C=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C1C=CC2CCC[C]2C=1")])], degeneracy=4, pairs=[[Molecule(SMILES="C1C=CC2CCCC=2C=1"), Molecule(SMILES="C1C=CC2CCC[C]2C=1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C1C=CC2CCC[C]2C=1")]])
# Reactant SMILES:
# C1C=CC2CCC[C]2C=1
# Product SMILES
# C1C=CC2CCCC=2C=1
# [H]
#
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cb-R!H_Cb-R!H', 'HJ']
# Cb-R!H_Cb-R!H
# HJ
# ===============
# One RMG match for this reaction.
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C1C=CC2CCC=C2C=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C1C=CC2CCC[C]2C=1")])], pairs=[[Molecule(SMILES="C1C=CC2CCC=C2C=1"), Molecule(SMILES="C1C=CC2CCC[C]2C=1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C1C=CC2CCC[C]2C=1")]])
# Reactant SMILES:
# C1C=CC2CCC[C]2C=1
# Product SMILES
# C1C=CC2CCC=C2C=1
# [H]
#
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CsH_Cds-CdCs', 'HJ']
# Cds-CsH_Cds-CdCs
# HJ
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i7 <=> p1 + CH3
#
# Reactant SMILES:
# CC[CH]c1ccccc1
# Product SMILES
# C=Cc1ccccc1
# [CH3]
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-HH_Cds-CbH', 'CsJ-HHH']
# Cds-HH_Cds-CbH
# CsJ-HHH
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=Cc1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="[CH3]")])], products=[Species(label="", molecule=[Molecule(SMILES="CC[CH]c1ccccc1")])], pairs=[[Molecule(SMILES="C=Cc1ccccc1"), Molecule(SMILES="CC[CH]c1ccccc1")], [Molecule(SMILES="[CH3]"), Molecule(SMILES="CC[CH]c1ccccc1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-HH_Cds-CdH', 'CsJ-HHH']
# Cds-HH_Cds-CdH
# CsJ-HHH
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CC1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[CH3]")])], products=[Species(label="", molecule=[Molecule(SMILES="CC[CH]C1C=CC=CC=1")])], pairs=[[Molecule(SMILES="C=CC1C=CC=CC=1"), Molecule(SMILES="CC[CH]C1C=CC=CC=1")], [Molecule(SMILES="[CH3]"), Molecule(SMILES="CC[CH]C1C=CC=CC=1")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i7 <=> p3 + H
#
# Reactant SMILES:
# CC[CH]c1ccccc1
# Product SMILES
# CC=Cc1ccccc1
# [H]
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CsH_Cds-CbH', 'HJ']
# Cds-CsH_Cds-CbH
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="CC=Cc1ccccc1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="CC[CH]c1ccccc1")])], pairs=[[Molecule(SMILES="CC=Cc1ccccc1"), Molecule(SMILES="CC[CH]c1ccccc1")], [Molecule(SMILES="[H]"), Molecule(SMILES="CC[CH]c1ccccc1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cds-CsH_Cds-CdH', 'HJ']
# Cds-CsH_Cds-CdH
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="CC=CC1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="CC[CH]C1C=CC=CC=1")])], pairs=[[Molecule(SMILES="CC=CC1C=CC=CC=1"), Molecule(SMILES="CC[CH]C1C=CC=CC=1")], [Molecule(SMILES="[H]"), Molecule(SMILES="CC[CH]C1C=CC=CC=1")]])
# ===============
# There are multiple RMG matches for this reaction. You have to manually create this training reaction
#
# i6 <=> p2 + H
#
# Reactant SMILES:
# C=CCC1=CC=C[CH]C1
# Product SMILES
# C=CCc1ccccc1
# [H]
#
# The following families and templates were matched:
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cb-H_Cb-H', 'HJ']
# Cb-H_Cb-H
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CCC1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C=CCC1=CC=C[CH]C1")])], degeneracy=4, pairs=[[Molecule(SMILES="C=CCC1C=CC=CC=1"), Molecule(SMILES="C=CCC1=CC=C[CH]C1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C=CCC1=CC=C[CH]C1")]])
# Matched Family: R_Addition_MultipleBond
# Matched Template: ['Cb-H_Cb-R!H', 'HJ']
# Cb-H_Cb-R!H
# HJ
# Reaction(reactants=[Species(label="", molecule=[Molecule(SMILES="C=CCC1C=CC=CC=1")]), Species(label="", molecule=[Molecule(SMILES="[H]")])], products=[Species(label="", molecule=[Molecule(SMILES="C=CC[C]1C=CC=CC1")])], degeneracy=4, pairs=[[Molecule(SMILES="C=CCC1C=CC=CC=1"), Molecule(SMILES="C=CC[C]1C=CC=CC1")], [Molecule(SMILES="[H]"), Molecule(SMILES="C=CC[C]1C=CC=CC1")]])
# ===============

# %%
for familyName in reactionDict:
    print 'Adding training reactions for family: ' + familyName
    kineticFamily = database.kinetics.families[familyName]
    trainingDatabase = None
    for depository in kineticFamily.depositories:
            if depository.label.endswith('training'):
                trainingDatabase = depository
                break
    reactions = reactionDict[familyName]
    print 'reactions.py previously has {} rxns. Now adding {} new rxn(s).'.format(len(trainingDatabase.entries.values()), len(reactions))
    print '================='
    kineticFamily.saveTrainingReactions(reactions, shortDesc='Training reaction from kinetics library: {0}'.format(libraryName))
# Out:
# Adding training reactions for family: Intra_R_Add_Exocyclic
# reactions.py previously has 8 rxns. Now adding 2 new rxn(s).
# =================
# Adding training reactions for family: R_Addition_MultipleBond
# reactions.py previously has 77 rxns. Now adding 5 new rxn(s).
# =================

# %% [markdown]
# # How saveTrainingReaction works
#
# This part of the script is commented and should not be run.  It serves only to demonstrate how the code for saving the training reactions works.
#
# ## get speciesDict
#
# ### load existing species as an intial speciesDict

# %%
# import os
# from rmgpy.data.base import Database

# training_path = os.path.join(settings['database.directory'], \
#                              'kinetics', 'families', 'R_Addition_MultipleBond', 'training')

# dictionary_file = os.path.join(training_path, 'dictionary.txt')

# # Load the existing set of the species of the training reactions
# speciesDict = Database().getSpecies(dictionary_file)

# %% [markdown]
# ### for one family check uniqueness of each species in the lib_rxns

# %%
# familyName = 'R_Addition_MultipleBond'
# print 'Adding training reactions for family: ' + familyName
# kineticFamily = database.kinetics.families[familyName]
# reactions = reactionDict[familyName]

# for rxn in reactions:
#     for spec in (rxn.reactants + rxn.products):
#         for ex_spec_label in speciesDict:
#             ex_spec = speciesDict[ex_spec_label]
#             if ex_spec.molecule[0].getFormula() != spec.molecule[0].getFormula():
#                 continue
#             else:
#                 spec_labeledAtoms = spec.molecule[0].getLabeledAtoms()
#                 ex_spec_labeledAtoms = ex_spec.molecule[0].getLabeledAtoms()
#                 initialMap = {}
#                 try:
#                     for atomLabel in spec_labeledAtoms:
#                         initialMap[spec_labeledAtoms[atomLabel]] = ex_spec_labeledAtoms[atomLabel]
#                 except KeyError:
#                     # atom labels did not match, therefore not a match
#                     continue
#                 if spec.molecule[0].isIsomorphic(ex_spec.molecule[0],initialMap):
#                     spec.label = ex_spec.label
#                     break
#         else:# no isomorphic existing species found
#             spec_formula = spec.molecule[0].getFormula()
#             if spec_formula not in speciesDict:
#                 spec.label = spec_formula
#             else:
#                 index = 2
#                 while (spec_formula + '-{}'.format(index)) in speciesDict:
#                     index += 1
#                 spec.label = spec_formula + '-{}'.format(index)
#             speciesDict[spec.label] = spec

# %% [markdown]
# ## save to files
#
# Save reactionDict to reactions.py and speciesDict to dictionary.txt

# %%
# # try to append 
# training_file = open(os.path.join(settings['database.directory'], 'kinetics', 'families', \
#             kineticFamily.label, 'training', 'reactions_test.py'), 'a')

# training_file.write("\n\n")

# %%
# # find the largest reaction index
# for depository in kineticFamily.depositories:
#     if depository.label.endswith('training'):
#         break
# else:
#     logging.info('Could not find training depository in family {0}.'.format(kineticFamily.label))
#     logging.info('Starting a new one')
#     depository = KineticsDepository()
#     kineticFamily.depositories.append(depository)

# trainingDatabase = depository
# indices = [entry.index for entry in trainingDatabase.entries.values()]
# if indices:
#     maxIndex = max(indices)
# else:
#     maxIndex = 0

# %%
# # save reactions.py
# from rmgpy.data.base import Entry
# for i, reaction in enumerate(reactions):    
#     entry = Entry(
#         index = maxIndex+i+1,
#         label = str(reaction),
#         item = reaction,
#         data = reaction.kinetics,
#         reference = None,
#         referenceType = '',
#         shortDesc = unicode(''),
#         longDesc = unicode(''),
#         rank = 3,
#         )
#     print reaction
#     kineticFamily.saveEntry(training_file, entry)

# training_file.close()

# %%
# # save dictionary.txt
# directory_test_file = os.path.join(training_path, 'directory_test.txt')
# with open(directory_test_file, 'w') as f:
#     for label in speciesDict.keys():
#         f.write(speciesDict[label].molecule[0].toAdjacencyList(label=label, removeH=False))
#         f.write('\n')
# f.close()
